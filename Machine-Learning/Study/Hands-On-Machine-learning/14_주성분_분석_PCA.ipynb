# %%
import numpy as np
import matplotlib.pyplot as plt
def draw_fruits(arr, ratio=1):
    n = len(arr)

    rows = int(np.ceil(n/10))

    cols = n if rows < 2 else 10
    fig, axs = plt.subplots(rows, cols,
                            figsize=(cols*ratio, rows*ratio), squeeze=False)

    for i in range(rows):
        for j in range(cols):
            if i*10 + j < n:
                axs[i, j].imshow(arr[i*10 + j], cmap='gray_r')
            axs[i, j].axis('off')
    plt.show()

# %%
import numpy as np

# %%
fruits = np.load("./dataSet/fruits_300_data.npy")

# %%
fruits_2d = fruits.reshape(-1, 100*100)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=50)
pca.fit(fruits_2d)
# Out:
# PCA(n_components=50)

# %%
pca.components_.shape
# Out:
# (50, 10000)

# %%
draw_fruits(pca.components_.reshape(-1, 100, 100))

# %%
fruits_2d.shape
# Out:
# (300, 10000)

# %%
fruits_pca = pca.transform(fruits_2d)
fruits_pca.shape
# Out:
# (300, 50)

# %% [markdown]
# ## 원본 데이터 재구성

# %%
fruits_inverse = pca.inverse_transform(fruits_pca)

# %%
fruits_inverse.shape
# Out:
# (300, 10000)

# %%
fruits_reconstruct = fruits_inverse.reshape(-1, 100, 100)
for start in [0, 100, 200]:
    print(start)
    draw_fruits(fruits_reconstruct[start: start+100])
    print("\n")
# Out:
# 0
# 100
# 200

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# np.float64(0.921498110447859)

# %%
plt.plot(pca.explained_variance_ratio_)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
target = np.array([0]* 100 + [1] * 100 +  [2] * 100)

# %%
from sklearn.model_selection import cross_validate
scores = cross_validate(lr, fruits_2d, target)

# %%
np.mean(scores['test_score'])
# Out:
# np.float64(0.9966666666666667)

# %%
np.mean(scores['fit_time'])
# Out:
# np.float64(0.1503420352935791)

# %%
scores = cross_validate(lr, fruits_pca, target)

# %%
np.mean(scores['test_score'])
# Out:
# np.float64(0.9966666666666667)

# %%
np.mean(scores['fit_time'])
# Out:
# np.float64(0.005314683914184571)

# %%
pca = PCA(n_components=0.5)
pca.fit(fruits_2d)
# Out:
# PCA(n_components=0.5)

# %%
pca.n_components_
# Out:
# np.int64(2)

# %%
fruits_pca = pca.transform(fruits_2d)
fruits_pca.shape
# Out:
# (300, 2)

# %%
scores = cross_validate(lr, fruits_pca, target)
# Out:
# /Users/samoyed/Documents/Study/ML-Study/Machine-Learning/Study/Hands-On-Machine-learning/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/samoyed/Documents/Study/ML-Study/Machine-Learning/Study/Hands-On-Machine-learning/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
np.mean(scores['test_score'])
# Out:
# np.float64(0.9933333333333334)

# %%
np.mean(scores['fit_time'])
# Out:
# np.float64(0.009865093231201171)

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=3, random_state=42)
km.fit(fruits_pca)
np.unique(km.labels_, return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int32), array([110,  99,  91]))

# %%
for label in range(0, 3):
    draw_fruits(fruits[km.labels_ == label])
    print("\n")

# %%
for label in range(0, 3):
    data = fruits_pca[km.labels_ == label]
    plt.scatter(data[:,0], data[:, 1])
plt.legend(['apple', 'banana', 'pineapple'])
plt.show()
