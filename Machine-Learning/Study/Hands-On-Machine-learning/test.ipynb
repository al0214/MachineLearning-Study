# %%
import sys
import torch

print("1. Python 버전:", sys.version)
print("2. CUDA 가속 가능 여부:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("3. 연동된 GPU 모델:", torch.cuda.get_device_name(0))
    print("4. CUDA 버전:", torch.version.cuda)
# Out:
# 1. Python 버전: 3.10.13 (main, Sep 11 2023, 13:44:35) [GCC 11.2.0]
# 2. CUDA 가속 가능 여부: True
# 3. 연동된 GPU 모델: NVIDIA GeForce RTX 2060
# 4. CUDA 버전: 12.1

# %%
# !python --version
# Out:
# Python 3.10.13
