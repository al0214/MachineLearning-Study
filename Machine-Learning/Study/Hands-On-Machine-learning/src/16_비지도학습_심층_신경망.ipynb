# %%
import keras

# %%
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

# %%
from sklearn.model_selection import train_test_split

# %%
train_scaled = train_input / 255.0

# %%
train_scaled = train_scaled.reshape(-1, 28*28)

# %%
train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42
)

# %%
from keras.layers import Dense
from keras.models import Sequential

# %%
inputs = keras.layers.Input(shape=(784,))
dense1 = keras.layers.Dense(100, activation='sigmoid')
dense2 = keras.layers.Dense(10, activation='softmax')

# %%
model = keras.Sequential([inputs, dense1, dense2])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(784,)),
    keras.layers.Dense(100, activation='sigmoid', name='은닉층'),
    keras.layers.Dense(10, activation='softmax', name='출력층')
], name='패션 MNIST 모델')

# %%
model.summary()
# Out:
# Model: "패션 MNIST 모델"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 은닉층 (Dense)                  │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 출력층 (Dense)                  │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model = keras.Sequential()

# %%
model.add(keras.layers.Input(shape=(784,)))

# %%
model.add(keras.layers.Dense(100, activation='sigmoid'))

# %%
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - accuracy: 0.8043 - loss: 0.5741
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 646us/step - accuracy: 0.8506 - loss: 0.4132
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 626us/step - accuracy: 0.8629 - loss: 0.3792
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 631us/step - accuracy: 0.8715 - loss: 0.3562
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 659us/step - accuracy: 0.8771 - loss: 0.3388

# %%
model = keras.Sequential()
model.add(keras.layers.Input(shape=(28,28)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()
train_scaled = train_input / 255.0
train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42
)

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 662us/step - accuracy: 0.8110 - loss: 0.5308
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 692us/step - accuracy: 0.8585 - loss: 0.3919
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 619us/step - accuracy: 0.8726 - loss: 0.3537
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 857us/step - accuracy: 0.8804 - loss: 0.3299
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 619us/step - accuracy: 0.8864 - loss: 0.3154

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - accuracy: 0.8773 - loss: 0.3537
# [0.3537308871746063, 0.8772500157356262]

# %%
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
sgd = keras.optimizers.SGD()
model.compile(optimizer=sgd, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
sgd = keras.optimizers.SGD(learning_rate=0.1)

# %%
sgd = keras.optimizers.SGD(momentum=0.9, nesterov=True)

# %%
adagrad = keras.optimizers.Adagrad()
model.compile(optimizer=adagrad, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
rmsprop = keras.optimizers.RMSprop()
model.compile(optimizer=rmsprop, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model = keras.Sequential()
model.add(keras.layers.Input(shape=(28,28)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_scaled, train_target, epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 737us/step - accuracy: 0.8184 - loss: 0.5178
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 745us/step - accuracy: 0.8583 - loss: 0.3897
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 735us/step - accuracy: 0.8721 - loss: 0.3502
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 969us/step - accuracy: 0.8823 - loss: 0.3220
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 724us/step - accuracy: 0.8893 - loss: 0.3036

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - accuracy: 0.8780 - loss: 0.3290
# [0.3289566934108734, 0.878000020980835]

# %% [markdown]
# # torch 버전

# %%
from torchvision.datasets import FashionMNIST

# %%
fm_train = FashionMNIST(root='./dataSet', train=True, download=True)
fm_test = FashionMNIST(root='./dataSet', train=False, download=True)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
type(fm_train.data)
# Out:
# torch.Tensor

# %%
fm_train.data.shape
# Out:
# torch.Size([60000, 28, 28])

# %%
fm_test.data.shape
# Out:
# torch.Size([10000, 28, 28])

# %%
train_input = fm_train.data
train_target = fm_train.targets

# %%
train_scaled = train_input / 255.0

# %%
from sklearn.model_selection import train_test_split

# %%
train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42
)

# %%
f'{train_scaled.shape} {val_scaled.shape}'
# Out:
# 'torch.Size([48000, 28, 28]) torch.Size([12000, 28, 28])'

# %%
import torch.nn as nn

# %%
model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(784, 100),
    nn.ReLU(),
    nn.Linear(100, 10)
)

# %%
from torchinfo import summary

# %%
summary(model, input_size=(32, 28,28))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Sequential                               [32, 10]                  --
# ├─Flatten: 1-1                           [32, 784]                 --
# ├─Linear: 1-2                            [32, 100]                 78,500
# ├─ReLU: 1-3                              [32, 100]                 --
# ├─Linear: 1-4                            [32, 10]                  1,010
# ...
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 2.54
# ...
# Input size (MB): 0.10
# Forward/backward pass size (MB): 0.03
# Params size (MB): 0.32
# Estimated Total Size (MB): 0.45
# ...

# %%
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=100, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
import torch.optim as optim

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
epochs = 5
batches = int(len(train_scaled)/32)
for epoch in range(epochs):
    model.train()
    train_loss = 0
    for i in range(batches):
        inputs = train_scaled[i*32:(i+1)*32].to(device)
        targets =train_target[i*32:(i+1)*32].to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    print(f"에포크: {epoch+1}, 손실: {train_loss/batches:.4f}")
# Out:
# 에포크: 1, 손실: 0.5457
# 에포크: 2, 손실: 0.4044
# 에포크: 3, 손실: 0.3620
# 에포크: 4, 손실: 0.3340
# 에포크: 5, 손실: 0.3131

# %%
model.eval()
# 모델을 '평가 모드(evaluation mode)'로 전환합니다.
# Dropout이나 BatchNorm처럼 학습할 때와 평가할 때 다르게 동작하는 레이어들에게
# "지금은 검증 중이니 평가용 동작을 수행해라"라고 알립니다.

with torch.no_grad():
# 이 블록 내부에서 일어나는 모든 연산에 대해 기울기(Gradient) 추적을 비활성화합니다.
# 검증 단계에서는 역전파(Backpropagation)로 가중치를 업데이트할 필요가 없으므로,
# 메모리 사용량을 줄이고 연산 속도를 대폭 향상시킵니다.

    val_scaled = val_scaled.to(device)
    # 정규화된 검증 입력 데이터(X)를 모델이 위치한 장치(CPU 또는 GPU/CUDA)로 이동시킵니다.
    # 모델과 입력 데이터가 같은 장치에 있어야 연산이 가능합니다.

    val_target = val_target.to(device)
    # 검증 데이터의 정답 레이블(y)을 동일한 장치(CPU 또는 GPU)로 이동시킵니다.

    outputs = model(val_scaled)
    # 모델에 입력 데이터를 넣어 예측 결과(Logits 또는 확률값)를 출력합니다.
    # 결과 형태는 [배치 크기, 클래스 개수]의 2차원 텐서가 됩니다.

    predicts = torch.argmax(outputs, 1)
    # outputs의 1번 차원(클래스 축)을 기준으로 가장 높은 값을 가진 인덱스를 선택합니다.
    # 즉, 모델이 생각하는 가장 확률이 높은 클래스 번호(예측값)를 추출합니다.

    corrects = (predicts == val_target).sum().item()
    # (predicts == val_target): 예측값과 정답을 비교해 같으면 True(1), 다르면 False(0)로 구성된 텐서를 만듭니다.
    # .sum(): True의 개수(맞춘 개수)를 모두 더합니다.
    # .item(): 텐서 형태로 존재하는 결과에서 순수 파이썬 숫자(int) 값만 뽑아냅니다.

    print(f'outputs: {outputs[[0]]}\npredicts: {predicts[0]}\nval_target: {val_target[0]}\ncorrects: {corrects}')

accuarcy = corrects / len(val_target)
# 맞춘 개수(corrects)를 전체 검증 데이터 개수(len(val_target))로 나누어 정확도를 계산합니다.

print(f"검증 정확도: {accuarcy:.4f}")
# 계산된 정확도를 소수점 넷째 자리까지 포맷팅하여 화면에 출력합니다.
# Out:
# outputs: tensor([[ -6.6510, -10.4330,  -7.1383,  -7.0394,  -3.5461,  -1.6014,  -7.8291,
#           -2.0146,   9.0150, -10.0752]])
# predicts: 8
# val_target: 8
# corrects: 10479
# 검증 정확도: 0.8732
